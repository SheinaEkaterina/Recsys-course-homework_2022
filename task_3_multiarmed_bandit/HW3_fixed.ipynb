# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import time
from functools import partial

from scipy.stats import randint, uniform
from sim_lib import simulation

pd.options.mode.chained_assignment = None

# %%
def ucb(history: pd.DataFrame, a: float):
    ctr = (history['clicks'] / (history['impressions']+1)) + a * np.sqrt(2 * np.log(np.sum(history['impressions']+1)) / (history['impressions']+1))
    n = np.argmax(ctr)
    return history.index[n]

# %%
for a in [0.05, 0.25, 1, 2]:
    print(f'UCB with exploration ratio {a}')
    policy_ucb = partial(ucb, a=a)

    # seed for homework
    seed = 18475
    np.random.seed(seed=seed)

    start = time.time()
    output = simulation(policy_ucb, n=200000, seed=seed)
    end = time.time()
    print(f'Time: {end - start}')

    # ucb regret
    print(f"Regret {output['regret']}, avg_regret_per_round {output['regret']/output['rounds']}, total banners {output['total_banners']}")

    # ucb history
    print("History:")
    print(output['history'])
    print()
# Out:
# UCB with exploration ratio 0.05
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 894.7389967441559
# Regret 2393.889846978175, avg_regret_per_round 0.011969449234890874, total banners 184
# History:
#      impressions  clicks      lifetime         p  alpha   beta
# 153          4.0     0.0  18003.025431  0.220134      1      5
# 162        208.0    22.0   1537.166719  0.113780     23    187
# 172      21217.0  4628.0  19648.592394  0.219968   4629  16590
# 173          1.0     0.0  12771.474990  0.122694      1      2
# 180          1.0     0.0   4655.819793  0.020061      1      2
# 182          1.0     0.0    889.624649  0.004621      1      2
# 183          1.0     0.0  15187.163761  0.073886      1      2
#
# UCB with exploration ratio 0.25
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 1033.339672088623
# Regret 1081.2948199012806, avg_regret_per_round 0.005406474099506403, total banners 184
# History:
#      impressions  clicks      lifetime         p  alpha   beta
# 153      13528.0  2948.0  18003.025431  0.220134   2949  10581
# 162         55.0     4.0   1537.166719  0.113780      5     52
# 172      14116.0  3060.0  19648.592394  0.219968   3061  11057
# 173        160.0    22.0  12771.474990  0.122694     23    139
# 180         24.0     0.0   4655.819793  0.020061      1     25
# 182         24.0     0.0    889.624649  0.004621      1     25
# 183         24.0     0.0  15187.163761  0.073886      1     25
#
# UCB with exploration ratio 1
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 968.7766537666321
# Regret 10383.940007792513, avg_regret_per_round 0.05191970003896256, total banners 184
# History:
#      impressions  clicks      lifetime         p  alpha  beta
# 153      12076.0  2670.0  18003.025431  0.220134   2671  9407
# 162        836.0    88.0   1537.166719  0.113780     89   749
# 172      11174.0  2441.0  19648.592394  0.219968   2442  8734
# 173       1070.0   132.0  12771.474990  0.122694    133   939
# 180        356.0     8.0   4655.819793  0.020061      9   349
# 182        212.0     1.0    889.624649  0.004621      2   212
# 183        287.0    14.0  15187.163761  0.073886     15   274
#
# UCB with exploration ratio 2
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 1007.7566502094269
# Regret 19179.34166563474, avg_regret_per_round 0.0958967083281737, total banners 184
# History:
#      impressions  clicks      lifetime         p  alpha  beta
# 153       6828.0  1459.0  18003.025431  0.220134   1460  5370
# 162       1794.0   200.0   1537.166719  0.113780    201  1595
# 172       7816.0  1726.0  19648.592394  0.219968   1727  6091
# 173       2022.0   250.0  12771.474990  0.122694    251  1773
# 180        850.0    14.0   4655.819793  0.020061     15   837
# 182        230.0     1.0    889.624649  0.004621      2   230
# 183        269.0    13.0  15187.163761  0.073886     14   257

# %%
from scipy.stats import beta

def ts(history: pd.DataFrame):
    bts = beta.rvs(history['alpha'], history['beta'])
    n = np.argmax(bts)
    return history.index[n]

# %%
for ts_explore in [0.25, 1, 2, 4, 8]:
    print(f'TS with exploration ratio {ts_explore}')
    policy_ts = ts
    # seed for homework
    seed = 18475
    np.random.seed(seed=seed)

    start = time.time()
    output = simulation(policy_ts, n=200000, seed=seed, ts_explore=ts_explore)
    end = time.time()
    print(f'Time: {end - start}')

    # ts regret
    print(f"Regret {output['regret']}, avg_regret_per_round {output['regret']/output['rounds']}, total banners {output['total_banners']}")

    # ts history
    print("History:")
    print(output['history'])
    print()
# Out:
# TS with exploration ratio 0.25
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 673.6734704971313
# Regret 473.8732907752059, avg_regret_per_round 0.0023693664538760296, total banners 184
# History:
#      impressions  clicks      lifetime         p  alpha   beta
# 153      19798.0  4303.0  18003.025431  0.220134  17213  61981
# 162         11.0     0.0   1537.166719  0.113780      1     45
# 172         27.0     2.0  19648.592394  0.219968      9    101
# 173         11.0     0.0  12771.474990  0.122694      1     45
# 180         16.0     1.0   4655.819793  0.020061      5     61
# 182          6.0     0.0    889.624649  0.004621      1     25
# 183          5.0     0.0  15187.163761  0.073886      1     21
#
# TS with exploration ratio 1
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 685.7782120704651
# Regret 1223.6103636831504, avg_regret_per_round 0.006118051818415752, total banners 184
# History:
#      impressions  clicks      lifetime         p  alpha   beta
# 153      24135.0  5317.0  18003.025431  0.220134   5318  18819
# 162        113.0    12.0   1537.166719  0.113780     13    102
# 172       3521.0   734.0  19648.592394  0.219968    735   2788
# 173        150.0    17.0  12771.474990  0.122694     18    134
# 180         31.0     1.0   4655.819793  0.020061      2     31
# 182         19.0     0.0    889.624649  0.004621      1     20
# 183         26.0     1.0  15187.163761  0.073886      2     26
#
# TS with exploration ratio 2
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 652.3379652500153
# Regret 2015.1471481184897, avg_regret_per_round 0.010075735740592449, total banners 184
# History:
#      impressions  clicks      lifetime         p   alpha    beta
# 153      15327.0  3394.0  18003.025431  0.220134  1698.0  5967.5
# 162        195.0    19.0   1537.166719  0.113780    10.5    89.0
# 172       5817.0  1219.0  19648.592394  0.219968   610.5  2300.0
# 173        129.0    10.0  12771.474990  0.122694     6.0    60.5
# 180         56.0     2.0   4655.819793  0.020061     2.0    28.0
# 182         28.0     0.0    889.624649  0.004621     1.0    15.0
# 183         31.0     1.0  15187.163761  0.073886     1.5    16.0
#
# TS with exploration ratio 4
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 608.2757065296173
# Regret 3463.7468672610967, avg_regret_per_round 0.017318734336305482, total banners 184
# History:
#      impressions  clicks      lifetime         p   alpha     beta
# 153      16395.0  3637.0  18003.025431  0.220134  910.25  3190.50
# 162        430.0    53.0   1537.166719  0.113780   14.25    95.25
# 172       6248.0  1362.0  19648.592394  0.219968  341.50  1222.50
# 173        483.0    63.0  12771.474990  0.122694   16.75   106.00
# 180         75.0     0.0   4655.819793  0.020061    1.00    19.75
# 182         47.0     0.0    889.624649  0.004621    1.00    12.75
# 183         56.0     3.0  15187.163761  0.073886    1.75    14.25
#
# TS with exploration ratio 8
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 614.1608693599701
# Regret 5545.561371452203, avg_regret_per_round 0.027727806857261016, total banners 184
# History:
#      impressions  clicks      lifetime         p    alpha      beta
# 153       8589.0  1889.0  18003.025431  0.220134  237.125   838.500
# 162        664.0    73.0   1537.166719  0.113780   10.125    74.875
# 172      11131.0  2377.0  19648.592394  0.219968  298.125  1095.250
# 173       1035.0   143.0  12771.474990  0.122694   18.875   112.500
# 180        128.0     2.0   4655.819793  0.020061    1.250    16.750
# 182         79.0     0.0    889.624649  0.004621    1.000    10.875
# 183         71.0     2.0  15187.163761  0.073886    1.250     9.625

# %%
for ts_explore in [1/8, 2/8, 3/8, 5/8, 6/8, 7/8]:
    print(f'TS with exploration ratio {ts_explore}')
    policy_ts = ts
    # seed for homework
    seed = 18475
    np.random.seed(seed=seed)

    start = time.time()
    output = simulation(policy_ts, n=200000, seed=seed, ts_explore=ts_explore)
    end = time.time()
    print(f'Time: {end - start}')

    # ts regret
    print(f"Regret {output['regret']}, avg_regret_per_round {output['regret']/output['rounds']}, total banners {output['total_banners']}")

    # ts history
    print("History:")
    print(output['history'])
    print()
# Out:
# TS with exploration ratio 0.125
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 649.1415846347809
# Regret 294.8526633040943, avg_regret_per_round 0.0014742633165204715, total banners 184
# History:
#      impressions  clicks      lifetime         p  alpha    beta
# 153      27636.0  6033.0  18003.025431  0.220134  48265  172825
# 162          7.0     0.0   1537.166719  0.113780      1      57
# 172         13.0     1.0  19648.592394  0.219968      9      97
# 173          5.0     0.0  12771.474990  0.122694      1      41
# 180          5.0     0.0   4655.819793  0.020061      1      41
# 182          4.0     0.0    889.624649  0.004621      1      33
# 183         52.0     9.0  15187.163761  0.073886     73     345
#
# TS with exploration ratio 0.25
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 663.5902080535889
# Regret 473.8732907752059, avg_regret_per_round 0.0023693664538760296, total banners 184
# History:
#      impressions  clicks      lifetime         p  alpha   beta
# 153      19798.0  4303.0  18003.025431  0.220134  17213  61981
# 162         11.0     0.0   1537.166719  0.113780      1     45
# 172         27.0     2.0  19648.592394  0.219968      9    101
# 173         11.0     0.0  12771.474990  0.122694      1     45
# 180         16.0     1.0   4655.819793  0.020061      5     61
# 182          6.0     0.0    889.624649  0.004621      1     25
# 183          5.0     0.0  15187.163761  0.073886      1     21
#
# TS with exploration ratio 0.375
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 627.2051184177399
# Regret 541.3736086989129, avg_regret_per_round 0.0027068680434945646, total banners 184
# History:
#      impressions  clicks      lifetime         p         alpha          beta
# 153        528.0    96.0  18003.025431  0.220134    257.000000   1153.000000
# 162         14.0     0.0   1537.166719  0.113780      1.000000     38.333333
# 172      20517.0  4488.0  19648.592394  0.219968  11969.000000  42745.000000
# 173        115.0    16.0  12771.474990  0.122694     43.666667    265.000000
# 180         10.0     0.0   4655.819793  0.020061      1.000000     27.666667
# 182          9.0     0.0    889.624649  0.004621      1.000000     25.000000
# 183         28.0     3.0  15187.163761  0.073886      9.000000     67.666667
#
# TS with exploration ratio 0.625
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 514.0488212108612
# Regret 817.7630134366963, avg_regret_per_round 0.004088815067183481, total banners 184
# History:
#      impressions  clicks      lifetime         p   alpha     beta
# 153      20990.0  4634.0  18003.025431  0.220134  7415.4  26170.6
# 162         32.0     1.0   1537.166719  0.113780     2.6     50.6
# 172       6841.0  1533.0  19648.592394  0.219968  2453.8   8493.8
# 173         54.0     5.0  12771.474990  0.122694     9.0     79.4
# 180         26.0     1.0   4655.819793  0.020061     2.6     41.0
# 182         13.0     0.0    889.624649  0.004621     1.0     21.8
# 183         11.0     0.0  15187.163761  0.073886     1.0     18.6
#
# TS with exploration ratio 0.75
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 644.5168330669403
# Regret 956.2939828535399, avg_regret_per_round 0.0047814699142677, total banners 184
# History:
#      impressions  clicks      lifetime         p        alpha          beta
# 153      13112.0  2897.0  18003.025431  0.220134  3863.666667  13621.000000
# 162         27.0     0.0   1537.166719  0.113780     1.000000     37.000000
# 172       8071.0  1742.0  19648.592394  0.219968  2323.666667   8439.666667
# 173         76.0     8.0  12771.474990  0.122694    11.666667     91.666667
# 180         18.0     0.0   4655.819793  0.020061     1.000000     25.000000
# 182         15.0     0.0    889.624649  0.004621     1.000000     21.000000
# 183         13.0     0.0  15187.163761  0.073886     1.000000     18.333333
#
# TS with exploration ratio 0.875
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 585.3266010284424
# Regret 1136.752761603002, avg_regret_per_round 0.00568376380801501, total banners 184
# History:
#      impressions  clicks      lifetime         p        alpha          beta
# 153      18384.0  4038.0  18003.025431  0.220134  4615.857143  16396.428571
# 162        146.0    19.0   1537.166719  0.113780    22.714286    146.142857
# 172      10078.0  2240.0  19648.592394  0.219968  2561.000000   8958.714286
# 173        168.0    22.0  12771.474990  0.122694    26.142857    167.857143
# 180         38.0     2.0   4655.819793  0.020061     3.285714     42.142857
# 182         23.0     1.0    889.624649  0.004621     2.142857     26.142857
# 183         15.0     0.0  15187.163761  0.073886     1.000000     18.142857

# %%
for ts_explore in [1/16, 1.5/16, 1/32, 1.5/32, 1/64, 1.5/64]:
    print(f'TS with exploration ratio {ts_explore}')
    policy_ts = ts
    # seed for homework
    seed = 18475
    np.random.seed(seed=seed)

    start = time.time()
    output = simulation(policy_ts, n=200000, seed=seed, ts_explore=ts_explore)
    end = time.time()
    print(f'Time: {end - start}')

    # ts regret
    print(f"Regret {output['regret']}, avg_regret_per_round {output['regret']/output['rounds']}, total banners {output['total_banners']}")

    # ts history
    print("History:")
    print(output['history'])
    print()
# Out:
# TS with exploration ratio 0.0625
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 733.1378719806671
# Regret 880.5826089594907, avg_regret_per_round 0.0044029130447974536, total banners 184
# History:
#      impressions  clicks      lifetime         p  alpha    beta
# 153          7.0     0.0  18003.025431  0.220134      1     113
# 162          5.0     0.0   1537.166719  0.113780      1      81
# 172      14949.0  3190.0  19648.592394  0.219968  51041  188145
# 173          5.0     0.0  12771.474990  0.122694      1      81
# 180          2.0     0.0   4655.819793  0.020061      1      33
# 182          2.0     0.0    889.624649  0.004621      1      33
# 183          2.0     0.0  15187.163761  0.073886      1      33
#
# TS with exploration ratio 0.09375
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 540.5910313129425
# Regret 435.92099488904205, avg_regret_per_round 0.00217960497444521, total banners 184
# History:
#      impressions  clicks      lifetime         p         alpha           beta
# 153      17960.0  3936.0  18003.025431  0.220134  41985.000000  149590.333333
# 162          5.0     0.0   1537.166719  0.113780      1.000000      54.333333
# 172      14869.0  3287.0  19648.592394  0.219968  35062.333333  123542.333333
# 173          4.0     0.0  12771.474990  0.122694      1.000000      43.666667
# 180          4.0     0.0   4655.819793  0.020061      1.000000      43.666667
# 182          3.0     0.0    889.624649  0.004621      1.000000      33.000000
# 183          3.0     0.0  15187.163761  0.073886      1.000000      33.000000
#
# TS with exploration ratio 0.03125
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 628.9244675636292
# Regret 3557.61019306656, avg_regret_per_round 0.0177880509653328, total banners 184
# History:
#      impressions  clicks      lifetime         p  alpha    beta
# 153          4.0     0.0  18003.025431  0.220134      1     129
# 162          5.0     0.0   1537.166719  0.113780      1     161
# 172          5.0     0.0  19648.592394  0.219968      1     161
# 173      20706.0  2522.0  12771.474990  0.122694  80705  581889
# 180          2.0     0.0   4655.819793  0.020061      1      65
# 182          2.0     0.0    889.624649  0.004621      1      65
# 183          2.0     0.0  15187.163761  0.073886      1      65
#
# TS with exploration ratio 0.046875
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 637.0381133556366
# Regret 282.7790526278636, avg_regret_per_round 0.0014138952631393181, total banners 184
# History:
#      impressions  clicks      lifetime         p     alpha           beta
# 153      33013.0  7296.0  18003.025431  0.220134  155649.0  548630.333333
# 162          2.0     0.0   1537.166719  0.113780       1.0      43.666667
# 172          3.0     0.0  19648.592394  0.219968       1.0      65.000000
# 173          2.0     0.0  12771.474990  0.122694       1.0      43.666667
# 180          2.0     0.0   4655.819793  0.020061       1.0      43.666667
# 182          2.0     0.0    889.624649  0.004621       1.0      43.666667
# 183          2.0     0.0  15187.163761  0.073886       1.0      43.666667
#
# TS with exploration ratio 0.015625
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 757.711688041687
# Regret 3810.0013328058562, avg_regret_per_round 0.01905000666402928, total banners 184
# History:
#      impressions  clicks      lifetime         p   alpha    beta
# 153          4.0     0.0  18003.025431  0.220134       1     257
# 162          2.0     0.0   1537.166719  0.113780       1     129
# 172      19829.0  4378.0  19648.592394  0.219968  280193  988865
# 173          2.0     0.0  12771.474990  0.122694       1     129
# 180          1.0     0.0   4655.819793  0.020061       1      65
# 182          1.0     0.0    889.624649  0.004621       1      65
# 183          1.0     0.0  15187.163761  0.073886       1      65
#
# TS with exploration ratio 0.0234375
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 669.5846147537231
# Regret 686.3509381872768, avg_regret_per_round 0.003431754690936384, total banners 184
# History:
#      impressions  clicks      lifetime         p          alpha           beta
# 153          1.0     0.0  18003.025431  0.220134       1.000000      43.666667
# 162          1.0     0.0   1537.166719  0.113780       1.000000      43.666667
# 172      20325.0  4444.0  19648.592394  0.219968  189611.666667  677590.333333
# 173          1.0     0.0  12771.474990  0.122694       1.000000      43.666667
# 180          1.0     0.0   4655.819793  0.020061       1.000000      43.666667
# 182          1.0     0.0    889.624649  0.004621       1.000000      43.666667
# 183          1.0     0.0  15187.163761  0.073886       1.000000      43.666667

# %% [markdown]
# Изменение exploration-части у TS.
#
# `greedy = a/(a+b)`
# `exploration = 1/(a+b)`
# (из презентации)
# Между тем, `a/(a+b) = E Beta(a, b)`, и на деле у нас получается распределение, имеющее пик в области p (настоящего p баннера), и 0 везде в других местах
#
# Если взять `a'=a/c, b'=b/c`, тогда:
# `greedy' = a/c / (a/c + b/c) = a/(a+b) = greedy`, осталось тем же
# `exploration' = 1/(a/c + b/c) = c/(a+b) = c * exloration`, увеличилось в `c` раз
#
# Оптимальное `c = 1/8`, то есть делать очень мало exploration-а, и сильно быстрее сходиться к `a/(a+b) -> p`. Это работает хорошо, потому что баннеры умирают сами и нам не нужно делать exploration (как в случае, если бы со временем появлялись более крутые баннеры).
#
# Аналогично, достаточно маленький exploration в UCB работает хорошо.

# %%
def eps_greedy(history: pd.DataFrame, eps: float):
    if uniform.rvs() < eps:
        n = history.shape[0]
        return history.index[randint.rvs(0, n)]

    ctr = history['clicks'] / (history['impressions'] + 10)
    n = np.argmax(ctr)
    return history.index[n]

# %%
for eps in [0.06]:
    print(f"e-greedy with exploration ratio {eps}")
    policy_egreedy = partial(eps_greedy, eps=eps)
    # seed for homework
    seed = 18475
    np.random.seed(seed=seed)

    start = time.time()
    output = simulation(policy_egreedy, n=200000, seed=seed)
    end = time.time()
    print(f'Time: {end - start}')

    # e-greedy regret
    print(f"Regret {output['regret']}, avg_regret_per_round {output['regret']/output['rounds']}, total banners {output['total_banners']}")

    # e-greedy history
    print("History:")
    print(output['history'])
    print()
# Out:
# e-greedy with exploration ratio 0.06
# 1 impressions have been simulated
# 10001 impressions have been simulated
# 20001 impressions have been simulated
# 30001 impressions have been simulated
# 40001 impressions have been simulated
# 50001 impressions have been simulated
# 60001 impressions have been simulated
# 70001 impressions have been simulated
# 80001 impressions have been simulated
# 90001 impressions have been simulated
# 100001 impressions have been simulated
# 110001 impressions have been simulated
# 120001 impressions have been simulated
# 130001 impressions have been simulated
# 140001 impressions have been simulated
# 150001 impressions have been simulated
# 160001 impressions have been simulated
# 170001 impressions have been simulated
# 180001 impressions have been simulated
# 190001 impressions have been simulated
# Time: 599.8631372451782
# Regret 1540.7609683932544, avg_regret_per_round 0.007703804841966272, total banners 184
# History:
#      impressions  clicks      lifetime         p  alpha   beta
# 153      18970.0  4199.0  18003.025431  0.220134   4200  14772
# 162        228.0    26.0   1537.166719  0.113780     27    203
# 172        163.0    32.0  19648.592394  0.219968     33    132
# 173        170.0    18.0  12771.474990  0.122694     19    153
# 180         26.0     3.0   4655.819793  0.020061      4     24
# 182          6.0     0.0    889.624649  0.004621      1      7
# 183          1.0     0.0  15187.163761  0.073886      1      2

# %% [markdown]
# Итог: реализованы 2 полиси - UCB и TS. В UCB я добавил множитель к добавке, и самый оптимальный получился при a=0.25. Для TS я изменил simulation и в случае победы добавлял 1 к alpha, а в случае поражения ts_reward к beta баннера. Наиболее оптимальные ts_reward 2 и 4, они достаточно схожи. Итоговый наилучший regret получился похожим у UCB и TS и равен примерно 1050-1080, и это лучше бейзлайна, регрет которго 1540.
